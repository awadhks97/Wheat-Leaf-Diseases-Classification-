# %% [markdown]
# # **1. Import Libraries**

# %%
# --- Core Python Libraries ---
import os
import random
import numpy as np
import pandas as pd

# --- Visualization ---
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import seaborn as sns

# --- Image Handling ---
from PIL import Image

# --- TensorFlow / Keras ---
import tensorflow as tf
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import (
    Conv2D, MaxPooling2D, Flatten,
    Dense, Dropout, BatchNormalization
)
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# --- Evaluation ---
from sklearn.metrics import classification_report, confusion_matrix
from tensorflow.keras.callbacks import EarlyStopping

import ipywidgets as widgets
from IPython.display import display

# %% [markdown]
# # **1.1 Initialize Path**

# %%
# Define the base directory for the dataset
base_path = 'C:/Users/awadh/Wheat/Pest'

# Define the paths for the training and testing data
train_path = os.path.join(base_path, 'train')
test_path = os.path.join(base_path, 'test')

# %% [markdown]
# # **2. Preview Data**

# %%
# Get all classnames from directory
class_names = sorted(os.listdir(train_path))

print("Classes:", class_names)
print("Total number of classes:", len(class_names))
# Out:
# Classes: ['Aphid', 'Healthy', 'Mite', 'Stem fly']
# Total number of classes: 4

# %%
fig, axes = plt.subplots(4, 4, figsize=(6, 6))
fig.suptitle("Sample Image from Each Pest Class", fontsize=12, y=1.02)
axes = axes.ravel()

valid_ext = ('.png', '.jpg', '.jpeg', '.bmp', '.tiff', '.jfif')

for i, class_name in enumerate(class_names):
    class_dir = os.path.join(train_path, class_name)
    image_files = [f for f in os.listdir(class_dir) if f.lower().endswith(valid_ext)]
    
    if image_files:
        image_path = os.path.join(class_dir, random.choice(image_files))
        img = Image.open(image_path)
        axes[i].imshow(img)
        axes[i].set_title(class_name, fontsize=12)
        axes[i].axis("off")

for j in range(len(class_names), len(axes)):
    axes[j].axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# # **3. Data Exploration**

# %%
# Count images per class
class_counts = {
    cls: len(os.listdir(os.path.join(train_path, cls)))
    for cls in class_names
}

# Create DataFrame sorted by count
df_counts = pd.DataFrame(class_counts.items(), columns=['Class', 'Count'])
df_counts = df_counts.sort_values(by='Count', ascending=False)
df_counts.insert(0, 'sl.no', range(1, 1 + len(df_counts)))

print("Image counts per class:")
print(df_counts.to_string(index=False))

# Total images
total_images = df_counts['Count'].sum()
print(f"\nTotal number of images: {total_images}")
# Out:
# Image counts per class:
#  sl.no    Class  Count
#      1  Healthy   1000
#      2    Aphid    949
#      3     Mite    800
#      4 Stem fly    234
#
# Total number of images: 2983

# %% [markdown]
# # **4. Define and Load Data using Pipeline**

# %% [markdown]
# # 4.1 Preprocessing and Splitting Dataset

# %%
# Image dimensions and batch size
img_width, img_height = 100, 100
batch_size = 32

# Data generator with normalization and train/validation split
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.3
)

# Training data (80%)
train_generator = datagen.flow_from_directory(
    train_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training'
)

# Validation data (20%)
validation_generator = datagen.flow_from_directory(
    train_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation'
)

# Summary
print(f"Training images: {train_generator.n}")
print(f"Validation images: {validation_generator.n}")
print(f"Number of classes: {train_generator.num_classes}")
# Out:
# Found 2089 images belonging to 4 classes.
# Found 894 images belonging to 4 classes.
# Training images: 2089
# Validation images: 894
# Number of classes: 4

# %% [markdown]
# # 4.2 Data Augmentation

# %%
# Image dimensions and batch size
img_width, img_height = 100, 100
batch_size = 32

# Data generator with augmentation and validation split
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=25,
    width_shift_range=0.2,
    height_shift_range=0.2,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    brightness_range=[0.8, 1.2],
    fill_mode='nearest',
    validation_split=0.2
)

# Training data (80%)
train_generator = datagen.flow_from_directory(
    train_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',
    shuffle=True
)

# Validation data (20%)
validation_generator = datagen.flow_from_directory(
    train_path,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',
    shuffle=False
)

# Summary
print(f"Training images: {train_generator.n}")
print(f"Validation images: {validation_generator.n}")
print(f"Number of classes: {train_generator.num_classes}")
# Out:
# Found 2388 images belonging to 4 classes.
# Found 595 images belonging to 4 classes.
# Training images: 2388
# Validation images: 595
# Number of classes: 4

# %% [markdown]
# # **5. Model Evaluation**

# %%
# Number of classes and image dimensions
num_classes = train_generator.num_classes
img_width, img_height = 100, 100

# Use MirroredStrategy for multi-GPU or robust device placement
strategy = tf.distribute.MirroredStrategy()

with strategy.scope():
    model = tf.keras.Sequential([
        # Convolutional blocks
        tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
        tf.keras.layers.MaxPooling2D((2, 2)),
        
        tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        
        tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
        tf.keras.layers.MaxPooling2D((2, 2)),
        
        # Flatten and fully connected layers
        tf.keras.layers.Flatten(),
        tf.keras.layers.Dropout(0.5),
        tf.keras.layers.Dense(512, activation='relu'),
        tf.keras.layers.Dense(num_classes, activation='softmax')
    ])

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )

model.summary()
# Out:
# INFO:tensorflow:Using MirroredStrategy with devices ('/job:localhost/replica:0/task:0/device:GPU:0',)
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 98, 98, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 49, 49, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 47, 47, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 23, 23, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 21, 21, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 10, 10, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 8, 8, 128)         147584
#
#  max_pooling2d_3 (MaxPooling  (None, 4, 4, 128)        0
#  2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout (Dropout)           (None, 2048)              0
#
#  dense (Dense)               (None, 512)               1049088
#
#  dense_1 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 1,291,972
# Trainable params: 1,291,972
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define the number of training epochs
epochs = 200

# Early stopping callback to prevent overfitting
early_stop = EarlyStopping(
    monitor='val_loss',   
    patience=3,           
    restore_best_weights=True
)

# Start training
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // train_generator.batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // validation_generator.batch_size
)
# Out:
# Epoch 1/200
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# INFO:tensorflow:Reduce to /job:localhost/replica:0/task:0/device:CPU:0 then broadcast to ('/job:localhost/replica:0/task:0/device:CPU:0',).
# 74/74 [==============================] - 36s 401ms/step - loss: 1.1634 - accuracy: 0.4605 - val_loss: 0.9339 - val_accuracy: 0.5799
# Epoch 2/200
# 74/74 [==============================] - 32s 432ms/step - loss: 0.9764 - accuracy: 0.5870 - val_loss: 0.8912 - val_accuracy: 0.6094
# Epoch 3/200
# 74/74 [==============================] - 31s 417ms/step - loss: 0.9239 - accuracy: 0.6104 - val_loss: 0.9456 - val_accuracy: 0.6094
# Epoch 4/200
# 74/74 [==============================] - 32s 432ms/step - loss: 0.8682 - accuracy: 0.6329 - val_loss: 0.8424 - val_accuracy: 0.6319
# Epoch 5/200
# 74/74 [==============================] - 30s 414ms/step - loss: 0.8582 - accuracy: 0.6282 - val_loss: 0.7601 - val_accuracy: 0.6736
# Epoch 6/200
# 74/74 [==============================] - 31s 414ms/step - loss: 0.8508 - accuracy: 0.6371 - val_loss: 0.8431 - val_accuracy: 0.6181
# Epoch 7/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.8162 - accuracy: 0.6430 - val_loss: 0.8080 - val_accuracy: 0.6528
# Epoch 8/200
# 74/74 [==============================] - 30s 414ms/step - loss: 0.7846 - accuracy: 0.6613 - val_loss: 0.7994 - val_accuracy: 0.6319
# Epoch 9/200
# 74/74 [==============================] - 31s 421ms/step - loss: 0.7830 - accuracy: 0.6655 - val_loss: 0.8484 - val_accuracy: 0.6354
# Epoch 10/200
# 74/74 [==============================] - 33s 447ms/step - loss: 0.7767 - accuracy: 0.6677 - val_loss: 0.7642 - val_accuracy: 0.6372
# Epoch 11/200
# 74/74 [==============================] - 30s 406ms/step - loss: 0.7879 - accuracy: 0.6617 - val_loss: 0.7728 - val_accuracy: 0.6441
# Epoch 12/200
# 74/74 [==============================] - 31s 422ms/step - loss: 0.7686 - accuracy: 0.6719 - val_loss: 0.8224 - val_accuracy: 0.6424
# Epoch 13/200
# 74/74 [==============================] - 32s 426ms/step - loss: 0.7685 - accuracy: 0.6817 - val_loss: 0.7449 - val_accuracy: 0.6753
# Epoch 14/200
# 74/74 [==============================] - 32s 440ms/step - loss: 0.7452 - accuracy: 0.6778 - val_loss: 0.7383 - val_accuracy: 0.6736
# Epoch 15/200
# 74/74 [==============================] - 32s 438ms/step - loss: 0.7797 - accuracy: 0.6728 - val_loss: 0.8162 - val_accuracy: 0.6406
# Epoch 16/200
# 74/74 [==============================] - 31s 417ms/step - loss: 0.7305 - accuracy: 0.6846 - val_loss: 0.7127 - val_accuracy: 0.6562
# Epoch 17/200
# 74/74 [==============================] - 32s 428ms/step - loss: 0.7138 - accuracy: 0.6944 - val_loss: 0.7481 - val_accuracy: 0.6615
# Epoch 18/200
# 74/74 [==============================] - 30s 404ms/step - loss: 0.7008 - accuracy: 0.7037 - val_loss: 0.7095 - val_accuracy: 0.6806
# Epoch 19/200
# 74/74 [==============================] - 30s 400ms/step - loss: 0.6806 - accuracy: 0.7059 - val_loss: 0.6951 - val_accuracy: 0.6979
# Epoch 20/200
# 74/74 [==============================] - 30s 404ms/step - loss: 0.6685 - accuracy: 0.7135 - val_loss: 0.7072 - val_accuracy: 0.6788
# Epoch 21/200
# 74/74 [==============================] - 30s 400ms/step - loss: 0.6453 - accuracy: 0.7143 - val_loss: 0.7515 - val_accuracy: 0.6701
# Epoch 22/200
# 74/74 [==============================] - 29s 397ms/step - loss: 0.6581 - accuracy: 0.7067 - val_loss: 0.7264 - val_accuracy: 0.6667
# Epoch 23/200
# 74/74 [==============================] - 30s 405ms/step - loss: 0.6504 - accuracy: 0.7220 - val_loss: 0.6804 - val_accuracy: 0.6840
# Epoch 24/200
# 74/74 [==============================] - 30s 395ms/step - loss: 0.6700 - accuracy: 0.7148 - val_loss: 0.7363 - val_accuracy: 0.6875
# Epoch 25/200
# 74/74 [==============================] - 30s 400ms/step - loss: 0.6498 - accuracy: 0.7190 - val_loss: 0.6718 - val_accuracy: 0.6875
# Epoch 26/200
# 74/74 [==============================] - 30s 405ms/step - loss: 0.6283 - accuracy: 0.7186 - val_loss: 0.6603 - val_accuracy: 0.6753
# Epoch 27/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.6088 - accuracy: 0.7292 - val_loss: 0.6833 - val_accuracy: 0.6979
# Epoch 28/200
# 74/74 [==============================] - 30s 399ms/step - loss: 0.5979 - accuracy: 0.7432 - val_loss: 0.6644 - val_accuracy: 0.7014
# Epoch 29/200
# 74/74 [==============================] - 30s 407ms/step - loss: 0.6280 - accuracy: 0.7271 - val_loss: 0.6868 - val_accuracy: 0.6962
# Epoch 30/200
# 74/74 [==============================] - 30s 407ms/step - loss: 0.6156 - accuracy: 0.7356 - val_loss: 0.7023 - val_accuracy: 0.6649
# Epoch 31/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.6181 - accuracy: 0.7279 - val_loss: 0.6893 - val_accuracy: 0.6840
# Epoch 32/200
# 74/74 [==============================] - 30s 401ms/step - loss: 0.5716 - accuracy: 0.7534 - val_loss: 0.6705 - val_accuracy: 0.6823
# Epoch 33/200
# 74/74 [==============================] - 30s 410ms/step - loss: 0.5632 - accuracy: 0.7653 - val_loss: 0.6838 - val_accuracy: 0.6806
# Epoch 34/200
# 74/74 [==============================] - 29s 395ms/step - loss: 0.5676 - accuracy: 0.7500 - val_loss: 0.6905 - val_accuracy: 0.6979
# Epoch 35/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0.5578 - accuracy: 0.7632 - val_loss: 0.6939 - val_accuracy: 0.6910
# Epoch 36/200
# 74/74 [==============================] - 30s 404ms/step - loss: 0.5466 - accuracy: 0.7627 - val_loss: 0.6464 - val_accuracy: 0.7118
# Epoch 37/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.5348 - accuracy: 0.7674 - val_loss: 0.6649 - val_accuracy: 0.7135
# Epoch 38/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0.5324 - accuracy: 0.7619 - val_loss: 0.6718 - val_accuracy: 0.7014
# Epoch 39/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0.5442 - accuracy: 0.7568 - val_loss: 0.6181 - val_accuracy: 0.7188
# Epoch 40/200
# 74/74 [==============================] - 29s 394ms/step - loss: 0.5371 - accuracy: 0.7615 - val_loss: 0.6521 - val_accuracy: 0.7170
# Epoch 41/200
# 74/74 [==============================] - 30s 406ms/step - loss: 0.5588 - accuracy: 0.7615 - val_loss: 0.6800 - val_accuracy: 0.6979
# Epoch 42/200
# 74/74 [==============================] - 30s 398ms/step - loss: 0.5238 - accuracy: 0.7691 - val_loss: 0.6902 - val_accuracy: 0.6944
# Epoch 43/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0
200
# 74/74 [==============================] - 30s 401ms/step - loss: 0.3069 - accuracy: 0.8633 - val_loss: 0.6540 - val_accuracy: 0.7431
# Epoch 95/200
# 74/74 [==============================] - 30s 400ms/step - loss: 0.3185 - accuracy: 0.8705 - val_loss: 0.7310 - val_accuracy: 0.7691
# Epoch 96/200
# 74/74 [==============================] - 30s 406ms/step - loss: 0.3098 - accuracy: 0.8693 - val_loss: 0.6792 - val_accuracy: 0.7483
# Epoch 97/200
# 74/74 [==============================] - 31s 421ms/step - loss: 0.3136 - accuracy: 0.8684 - val_loss: 0.7205 - val_accuracy: 0.7431
# Epoch 98/200
# 74/74 [==============================] - 30s 407ms/step - loss: 0.3277 - accuracy: 0.8650 - val_loss: 0.6419 - val_accuracy: 0.7639
# Epoch 99/200
# 74/74 [==============================] - 29s 394ms/step - loss: 0.2975 - accuracy: 0.8807 - val_loss: 0.5894 - val_accuracy: 0.7743
# Epoch 100/200
# 74/74 [==============================] - 30s 401ms/step - loss: 0.2968 - accuracy: 0.8854 - val_loss: 0.6469 - val_accuracy: 0.7656
# Epoch 101/200
# 74/74 [==============================] - 30s 401ms/step - loss: 0.3009 - accuracy: 0.8744 - val_loss: 0.6738 - val_accuracy: 0.7760
# Epoch 102/200
# 74/74 [==============================] - 30s 401ms/step - loss: 0.2859 - accuracy: 0.8795 - val_loss: 0.7789 - val_accuracy: 0.7656
# Epoch 103/200
# 74/74 [==============================] - 29s 401ms/step - loss: 0.3064 - accuracy: 0.8680 - val_loss: 0.7290 - val_accuracy: 0.7622
# Epoch 104/200
# 74/74 [==============================] - 30s 399ms/step - loss: 0.2933 - accuracy: 0.8858 - val_loss: 0.7250 - val_accuracy: 0.7378
# Epoch 105/200
# 74/74 [==============================] - 30s 399ms/step - loss: 0.2740 - accuracy: 0.8905 - val_loss: 0.7231 - val_accuracy: 0.7795
# Epoch 106/200
# 74/74 [==============================] - 30s 404ms/step - loss: 0.2822 - accuracy: 0.8906 - val_loss: 0.6807 - val_accuracy: 0.7743
# Epoch 107/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0.2833 - accuracy: 0.8841 - val_loss: 0.7342 - val_accuracy: 0.7413
# Epoch 108/200
# 74/74 [==============================] - 30s 399ms/step - loss: 0.2680 - accuracy: 0.8922 - val_loss: 0.6575 - val_accuracy: 0.7535
# Epoch 109/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.2841 - accuracy: 0.8905 - val_loss: 0.7601 - val_accuracy: 0.7413
# Epoch 110/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.2679 - accuracy: 0.8939 - val_loss: 0.8248 - val_accuracy: 0.7153
# Epoch 111/200
# 74/74 [==============================] - 30s 406ms/step - loss: 0.2717 - accuracy: 0.8930 - val_loss: 0.6291 - val_accuracy: 0.7552
# Epoch 112/200
# 74/74 [==============================] - 30s 405ms/step - loss: 0.2884 - accuracy: 0.8829 - val_loss: 0.6759 - val_accuracy: 0.7674
# Epoch 113/200
# 74/74 [==============================] - 30s 404ms/step - loss: 0.2642 - accuracy: 0.8918 - val_loss: 0.7538 - val_accuracy: 0.7535
# Epoch 114/200
# 74/74 [==============================] - 30s 398ms/step - loss: 0.2656 - accuracy: 0.8913 - val_loss: 0.6571 - val_accuracy: 0.7535
# Epoch 115/200
# 74/74 [==============================] - 30s 407ms/step - loss: 0.2952 - accuracy: 0.8803 - val_loss: 0.6543 - val_accuracy: 0.7812
# Epoch 116/200
# 74/74 [==============================] - 30s 404ms/step - loss: 0.2461 - accuracy: 0.8947 - val_loss: 0.6865 - val_accuracy: 0.7760
# Epoch 117/200
# 74/74 [==============================] - 29s 401ms/step - loss: 0.2836 - accuracy: 0.8807 - val_loss: 0.7065 - val_accuracy: 0.7431
# Epoch 118/200
# 74/74 [==============================] - 29s 397ms/step - loss: 0.2621 - accuracy: 0.8994 - val_loss: 0.7459 - val_accuracy: 0.7431
# Epoch 119/200
# 74/74 [==============================] - 30s 399ms/step - loss: 0.2449 - accuracy: 0.9053 - val_loss: 0.7167 - val_accuracy: 0.7743
# Epoch 120/200
# 74/74 [==============================] - 30s 406ms/step - loss: 0
200
# 74/74 [==============================] - 30s 405ms/step - loss: 0.2542 - accuracy: 0.9053 - val_loss: 0.7683 - val_accuracy: 0.7656
# Epoch 145/200
# 74/74 [==============================] - 29s 398ms/step - loss: 0.1927 - accuracy: 0.9223 - val_loss: 0.8423 - val_accuracy: 0.7708
# Epoch 146/200
# 74/74 [==============================] - 30s 405ms/step - loss: 0.2006 - accuracy: 0.9155 - val_loss: 0.7625 - val_accuracy: 0.7830
# Epoch 147/200
# 74/74 [==============================] - 30s 400ms/step - loss: 0.2194 - accuracy: 0.9104 - val_loss: 0.7623 - val_accuracy: 0.7656
# Epoch 148/200
# 74/74 [==============================] - 30s 407ms/step - loss: 0.2314 - accuracy: 0.9151 - val_loss: 0.7096 - val_accuracy: 0.7517
# Epoch 149/200
# 74/74 [==============================] - 30s 408ms/step - loss: 0.2065 - accuracy: 0.9134 - val_loss: 0.7694 - val_accuracy: 0.7708
# Epoch 150/200
# 74/74 [==============================] - 30s 412ms/step - loss: 0.2258 - accuracy: 0.9100 - val_loss: 0.7174 - val_accuracy: 0.7778
# Epoch 151/200
# 74/74 [==============================] - 30s 409ms/step - loss: 0.2292 - accuracy: 0.9104 - val_loss: 0.7315 - val_accuracy: 0.7847
# Epoch 152/200
# 74/74 [==============================] - 30s 408ms/step - loss: 0.2061 - accuracy: 0.9223 - val_loss: 0.7167 - val_accuracy: 0.8090
# Epoch 153/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0.2039 - accuracy: 0.9219 - val_loss: 0.8312 - val_accuracy: 0.7413
# Epoch 154/200
# 74/74 [==============================] - 29s 400ms/step - loss: 0.2495 - accuracy: 0.9066 - val_loss: 0.6454 - val_accuracy: 0.7917
# Epoch 155/200
# 74/74 [==============================] - 30s 405ms/step - loss: 0.1986 - accuracy: 0.9300 - val_loss: 0.7159 - val_accuracy: 0.7795
# Epoch 156/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0.2072 - accuracy: 0.9126 - val_loss: 0.7559 - val_accuracy: 0.7691
# Epoch 157/200
# 74/74 [==============================] - 30s 407ms/step - loss: 0.2254 - accuracy: 0.9126 - val_loss: 0.6651 - val_accuracy: 0.7847
# Epoch 158/200
# 74/74 [==============================] - 30s 405ms/step - loss: 0.2095 - accuracy: 0.9253 - val_loss: 0.7289 - val_accuracy: 0.7708
# Epoch 159/200
# 74/74 [==============================] - 30s 407ms/step - loss: 0.2223 - accuracy: 0.9228 - val_loss: 0.9835 - val_accuracy: 0.7951
# Epoch 160/200
# 74/74 [==============================] - 30s 406ms/step - loss: 0.2296 - accuracy: 0.9104 - val_loss: 0.7790 - val_accuracy: 0.7830
# Epoch 161/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.2019 - accuracy: 0.9215 - val_loss: 0.7861 - val_accuracy: 0.7795
# Epoch 162/200
# 74/74 [==============================] - 30s 410ms/step - loss: 0.1879 - accuracy: 0.9300 - val_loss: 0.7573 - val_accuracy: 0.7708
# Epoch 163/200
# 74/74 [==============================] - 30s 407ms/step - loss: 0.2319 - accuracy: 0.9130 - val_loss: 0.8421 - val_accuracy: 0.7708
# Epoch 164/200
# 74/74 [==============================] - 30s 413ms/step - loss: 0.2074 - accuracy: 0.9202 - val_loss: 0.7266 - val_accuracy: 0.7743
# Epoch 165/200
# 74/74 [==============================] - 30s 409ms/step - loss: 0.1916 - accuracy: 0.9253 - val_loss: 0.8055 - val_accuracy: 0.7691
# Epoch 166/200
# 74/74 [==============================] - 30s 408ms/step - loss: 0.2193 - accuracy: 0.9160 - val_loss: 0.6263 - val_accuracy: 0.7899
# Epoch 167/200
# 74/74 [==============================] - 30s 408ms/step - loss: 0.1990 - accuracy: 0.9219 - val_loss: 0.7208 - val_accuracy: 0.7812
# Epoch 168/200
# 74/74 [==============================] - 30s 406ms/step - loss: 0.1980 - accuracy: 0.9244 - val_loss: 0.8538 - val_accuracy: 0.7674
# Epoch 169/200
# 74/74 [==============================] - 30s 409ms/step - loss: 0.2257 - accuracy: 0.9109 - val_loss: 0.8290 - val_accuracy: 0.7656
# Epoch 170/200
# 74/74 [==============================] - 30s 408ms/step - loss: 0.1987 - accuracy: 0.9211 - val_loss: 0.6573 - val_accuracy: 0.7969
# Epoch 171/200
# 74/74 [==============================] - 30s 408ms/step - loss: 0.1723 - accuracy: 0.9320 - val_loss: 0.7259 - val_accuracy: 0.7847
# Epoch 172/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.1868 - accuracy: 0.9253 - val_loss: 0.8046 - val_accuracy: 0.7778
# Epoch 173/200
# 74/74 [==============================] - 29s 400ms/step - loss: 0.1922 - accuracy: 0.9232 - val_loss: 0.7435 - val_accuracy: 0.7760
# Epoch 174/200
# 74/74 [==============================] - 30s 400ms/step - loss: 0.1730 - accuracy: 0.9325 - val_loss: 0.6967 - val_accuracy: 0.7865
# Epoch 175/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0.1917 - accuracy: 0.9351 - val_loss: 0.8257 - val_accuracy: 0.7795
# Epoch 176/200
# 74/74 [==============================] - 30s 397ms/step - loss: 0.1731 - accuracy: 0.9317 - val_loss: 0.9301 - val_accuracy: 0.7674
# Epoch 177/200
# 74/74 [==============================] - 30s 400ms/step - loss: 0.1861 - accuracy: 0.9329 - val_loss: 0.7929 - val_accuracy: 0.7743
# Epoch 178/200
# 74/74 [==============================] - 30s 400ms/step - loss: 0.1944 - accuracy: 0.9295 - val_loss: 0.7887 - val_accuracy: 0.7708
# Epoch 179/200
# 74/74 [==============================] - 29s 400ms/step - loss: 0.1587 - accuracy: 0.9389 - val_loss: 0.9709 - val_accuracy: 0.7604
# Epoch 180/200
# 74/74 [==============================] - 30s 398ms/step - loss: 0.2023 - accuracy: 0.9244 - val_loss: 0.8664 - val_accuracy: 0.7639
# Epoch 181/200
# 74/74 [==============================] - 30s 406ms/step - loss: 0.2023 - accuracy: 0.9274 - val_loss: 0.8748 - val_accuracy: 0.7448
# Epoch 182/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.1759 - accuracy: 0.9304 - val_loss: 0.8452 - val_accuracy: 0.7760
# Epoch 183/200
# 74/74 [==============================] - 30s 406ms/step - loss: 0.2178 - accuracy: 0.9244 - val_loss: 0.7175 - val_accuracy: 0.7986
# Epoch 184/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.1546 - accuracy: 0.9478 - val_loss: 0.7393 - val_accuracy: 0.7795
# Epoch 185/200
# 74/74 [==============================] - 29s 399ms/step - loss: 0.2381 - accuracy: 0.9143 - val_loss: 0.7990 - val_accuracy: 0.7812
# Epoch 186/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0.1890 - accuracy: 0.9270 - val_loss: 0.7221 - val_accuracy: 0.7760
# Epoch 187/200
# 74/74 [==============================] - 29s 398ms/step - loss: 0.1777 - accuracy: 0.9380 - val_loss: 0.7222 - val_accuracy: 0.7812
# Epoch 188/200
# 74/74 [==============================] - 30s 407ms/step - loss: 0.1782 - accuracy: 0.9329 - val_loss: 0.7364 - val_accuracy: 0.7708
# Epoch 189/200
# 74/74 [==============================] - 30s 401ms/step - loss: 0.1858 - accuracy: 0.9317 - val_loss: 0.7538 - val_accuracy: 0.7760
# Epoch 190/200
# 74/74 [==============================] - 30s 404ms/step - loss: 0.1510 - accuracy: 0.9397 - val_loss: 0.7980 - val_accuracy: 0.7969
# Epoch 191/200
# 74/74 [==============================] - 30s 410ms/step - loss: 0.1674 - accuracy: 0.9338 - val_loss: 0.7865 - val_accuracy: 0.7830
# Epoch 192/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.1662 - accuracy: 0.9334 - val_loss: 0.8120 - val_accuracy: 0.7795
# Epoch 193/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0.1769 - accuracy: 0.9351 - val_loss: 0.9461 - val_accuracy: 0.7639
# Epoch 194/200
# 74/74 [==============================] - 29s 398ms/step - loss: 0.1757 - accuracy: 0.9308 - val_loss: 0.8895 - val_accuracy: 0.7674
# Epoch 195/200
# 74/74 [==============================] - 30s 399ms/step - loss: 0.1524 - accuracy: 0.9410 - val_loss: 0.7930 - val_accuracy: 0.7708
# Epoch 196/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.1530 - accuracy: 0.9440 - val_loss: 0.9312 - val_accuracy: 0.7431
# Epoch 197/200
# 74/74 [==============================] - 30s 403ms/step - loss: 0.1604 - accuracy: 0.9397 - val_loss: 0.7663 - val_accuracy: 0.7691
# Epoch 198/200
# 74/74 [==============================] - 29s 400ms/step - loss: 0.1741 - accuracy: 0.9334 - val_loss: 0.9038 - val_accuracy: 0.7778
# Epoch 199/200
# 74/74 [==============================] - 30s 402ms/step - loss: 0.1762 - accuracy: 0.9325 - val_loss: 0.8684 - val_accuracy: 0.7934
# Epoch 200/200
# 74/74 [==============================] - 30s 404ms/step - loss: 0.1945 - accuracy: 0.9261 - val_loss: 0.7700 - val_accuracy: 0.7865

# %%
# Extract metrics from the training history
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

# Plot training and validation accuracy & loss
plt.figure(figsize=(15, 6))

# Accuracy plot
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')
plt.grid(True)

# Loss plot
plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc='upper right')
plt.grid(True)

plt.tight_layout()
plt.show()

# %%
# Get the final validation metrics
final_accuracy = history.history['val_accuracy'][-1]
final_loss = history.history['val_loss'][-1]

print(f"Final Validation Accuracy: {final_accuracy:.4f}")
print(f"Final Validation Loss: {final_loss:.4f}")
# Out:
# Final Validation Accuracy: 0.7865
# Final Validation Loss: 0.7700

# %%
# Get the true labels and predicted labels for the validation set
validation_labels = validation_generator.classes
validation_steps = validation_generator.samples // validation_generator.batch_size
predictions = model.predict(validation_generator, steps=validation_steps)
predicted_labels = np.argmax(predictions, axis=1)

# Get the class labels from the generator
class_labels = list(validation_generator.class_indices.keys())

# Generate and print the classification report
report = classification_report(validation_labels[:len(predicted_labels)], predicted_labels, target_names=class_labels)
print("\nClassification Report:\n", report)
# Out:
# 18/18 [==============================] - 5s 253ms/step
#
# Classification Report:
#                precision    recall  f1-score   support
#
#        Aphid       0.69      0.80      0.74       189
#      Healthy       0.92      0.97      0.94       200
#         Mite       0.72      0.56      0.63       160
#     Stem fly       0.71      0.56      0.62        27
#
#     accuracy                           0.78       576
#    macro avg       0.76      0.72      0.73       576
# weighted avg       0.78      0.78      0.77       576

# %%
# Generate the confusion matrix
cm = confusion_matrix(validation_labels[:len(predicted_labels)], predicted_labels)

# Plot the confusion matrix as a heatmap
plt.figure(figsize=(10, 10))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_labels, yticklabels=class_labels)
plt.title('Confusion Matrix', fontsize=20)
plt.xlabel('Predicted Label', fontsize=16)
plt.ylabel('True Label', fontsize=16)
plt.xticks(rotation=90)
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **6. Test model with Unseen Data**

# %%
# Save the model in the HDF5 (.h5) format
model.save('C:/Users/awadh/Wheat/my_wheat_model.h5')
print("Model saved successfully as 'my_wheat_model.h5'.")
# Out:
# Model saved successfully as 'my_wheat_model.h5'.

# %%
# -------------------------------
# IMPORTS
# -------------------------------
import os
import random
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import tensorflow as tf
import ipywidgets as widgets
from IPython.display import display
from tensorflow.keras.models import load_model

# -------------------------------
# FORCE CPU (avoid transfer manager errors)
# -------------------------------
os.environ["CUDA_VISIBLE_DEVICES"] = ""
os.environ["TF_ENABLE_ONEDNN_OPTS"] = "0"

# -------------------------------
# LOAD MODEL
# -------------------------------
model_path = 'C:/Users/awadh/Wheat/my_wheat_model.h5'
model = load_model(model_path, compile=False)

# -------------------------------
# CLASS LABELS
# -------------------------------
class_labels = ['Aphid', 'Healthy', 'Mite', 'Stem fly']

# -------------------------------
# IMAGE PREPROCESSING
# -------------------------------
def preprocess_image(image_path, target_size=(100, 100)):
    """Load image, resize, normalize and expand dimensions for prediction."""
    img = Image.open(image_path).convert("RGB")
    img = img.resize(target_size)
    img_array = np.array(img).astype("float32") / 255.0
    return np.expand_dims(img_array, axis=0)

# -------------------------------
# PREDICTION FUNCTION
# -------------------------------
def predict_image(img_path):
    """Predict and return figure + label instead of showing directly."""
    x = preprocess_image(img_path)
    x = tf.convert_to_tensor(x)

    with tf.device("/CPU:0"):
        preds = model(x, training=False).numpy()

    idx = np.argmax(preds, axis=1)[0]
    label = class_labels[idx]
    conf = preds[0][idx] * 100

    # Plot image
    fig, ax = plt.subplots(figsize=(4, 4))
    ax.imshow(Image.open(img_path))
    ax.axis("off")
    ax.set_title(f"Predicted: {label} ({conf:.2f}%)", fontsize=12)

    # Return figure and details
    return fig, label, conf, os.path.basename(img_path)

# -------------------------------
# TEST IMAGE SEARCH
# -------------------------------
test_path = 'C:/Users/awadh/Wheat/Pest/test'
valid_ext = ('.png', '.jpg', '.jpeg', '.bmp', '.tiff', '.jfif')

# Search recursively for images in subfolders
image_files = []
for root, dirs, files in os.walk(test_path):
    for f in files:
        if f.lower().endswith(valid_ext):
            image_files.append(os.path.join(root, f))

# Relative paths for dropdown display
dropdown_options = [os.path.relpath(f, test_path) for f in image_files]

print(f"✅ Found {len(image_files)} images for prediction.")

# -------------------------------
# WIDGETS
# -------------------------------
dropdown = widgets.Dropdown(
    options=dropdown_options if dropdown_options else ["(no images found)"],
    description="Choose Image:",
    layout=widgets.Layout(width="60%")
)

count_box = widgets.BoundedIntText(
    value=1,
    min=1,
    max=max(1, len(image_files)),
    step=1,
    description="How many:",
    layout=widgets.Layout(width="60%")
)

button = widgets.Button(description="Predict ✅", button_style="success")
output = widgets.Output()

# -------------------------------
# BUTTON CALLBACK
# -------------------------------
def on_submit(b):
    output.clear_output()
    with output:
        if not image_files:
            print("⚠️ No images found in the test directory.")
            return

        start_index = dropdown_options.index(dropdown.value)
        num = min(count_box.value, len(image_files) - start_index)
        selected_files = image_files[start_index:start_index + num]

        for f in selected_files:
            fig, label, conf, filename = predict_image(f)
            display(fig)
            print(f"📂 File: {filename}")
            print(f"✅ Prediction: {label} ({conf:.2f}%)\n")
            plt.close(fig)

button.on_click(on_submit)

# -------------------------------
# DISPLAY UI
# -------------------------------
display(widgets.VBox([dropdown, count_box, button, output]))
# Out:
# ✅ Found 200 images for prediction.
# VBox(children=(Dropdown(description='Choose Image:', layout=Layout(width='60%'), options=('aphid_test\\aphid_2…
